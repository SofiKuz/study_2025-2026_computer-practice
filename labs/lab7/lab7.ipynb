# %% [markdown]
# #### 1. Julia для науки о данных

# %% [markdown]
# #### 1.1. Считывание данных

# %%
# Обновление окружения:
using Pkg
Pkg.update
# Установка пакетов:
using Pkg
for p in ["CSV", "DataFrames", "RDatasets", "FileIO"]
    Pkg.add(p)
end
using CSV, DataFrames, DelimitedFiles
# Out:
#     Updating registry at `C:\Users\Ivan\.julia\registries\General.toml`
#    Resolving package versions...
#    Installed JpegTurbo_jll ───────────────── v3.1.0+1
#    Installed OffsetArrays ────────────────── v1.15.0
#    Installed GR_jll ──────────────────────── v0.73.10+0
#    Installed Xorg_xkbcomp_jll ────────────── v1.4.6+1
#    Installed Libmount_jll ────────────────── v2.40.2+1
#    Installed LERC_jll ────────────────────── v4.0.0+2
#    Installed OrdinaryDiffEqRosenbrock ────── v1.4.0
#    Installed FastGaussQuadrature ─────────── v1.0.2
#    Installed InlineStrings ───────────────── v1.4.2
#    Installed Xorg_libXinerama_jll ────────── v1.1.5+0
#    Installed Libgpg_error_jll ────────────── v1.51.0+0
#    Installed OrdinaryDiffEqSDIRK ─────────── v1.2.0
#    Installed OrdinaryDiffEqCore ──────────── v1.14.1
#    Installed Xorg_libxkbfile_jll ─────────── v1.1.2+1
#    Installed StaticArrays ────────────────── v1.9.9
#    Installed SciMLBase ───────────────────── v2.70.0
#    Installed BandedMatrices ──────────────── v1.9.0
#    Installed Pango_jll ───────────────────── v1.55.5+0
#    Installed OrdinaryDiffEqFIRK ──────────── v1.6.0
#    Installed xkbcommon_jll ───────────────── v1.4.1+2
#    Installed DiffEqBase ──────────────────── v6.161.0
#    Installed Bzip2_jll ───────────────────── v1.0.8+3
#    Installed SentinelArrays ──────────────── v1.4.8
#    Installed LZO_jll ─────────────────────── v2.10.2+2
#    Installed GR ──────────────────────────── v0.73.10
#    Installed XZ_jll ──────────────────────── v5.6.3+1
#    Installed WorkerUtilities ─────────────── v1.6.1
#    Installed GLFW_jll ────────────────────── v3.4.0+2
#    Installed FriBidi_jll ─────────────────── v1.0.16+0
#    Installed WeakRefStrings ──────────────── v1.4.2
#    Installed TranscodingStreams ──────────── v0.11.3
#    Installed CodecZlib ───────────────────── v0.7.6
#    Installed libpng_jll ──────────────────── v1.6.44+1
#    Installed StatsBase ───────────────────── v0.34.4
#    Installed OrdinaryDiffEqPDIRK ─────────── v1.2.0
#    Installed Expat_jll ───────────────────── v2.6.4+2
#    Installed Zstd_jll ────────────────────── v1.5.6+2
#    Installed NonlinearSolveBase ──────────── v1.4.0
#    Installed PooledArrays ────────────────── v1.4.3
#    Installed StochasticDiffEq ────────────── v6.72.1
#    Installed JLLWrappers ─────────────────── v1.7.0
#    Installed Libffi_jll ──────────────────── v3.2.2+2
#    Installed NonlinearSolveFirstOrder ────── v1.2.0
#    Installed Xorg_libXrender_jll ─────────── v0.9.11+1
#    Installed Xorg_libXi_jll ──────────────── v1.8.2+0
#    Installed OpenSpecFun_jll ─────────────── v0.5.5+1
#    Installed OrdinaryDiffEqExtrapolation ─── v1.3.0
#    Installed ArrayInterface ──────────────── v7.18.0
#    Installed DelayDiffEq ─────────────────── v5.51.0
#    Installed OrdinaryDiffEqExponentialRK ─── v1.2.0
#    Installed Xorg_libXcursor_jll ─────────── v1.2.3+0
#    Installed Libuuid_jll ─────────────────── v2.40.2+1
#    Installed Wayland_protocols_jll ───────── v1.36.0+0
#    Installed CSV ─────────────────────────── v0.10.15
#    Installed OrdinaryDiffEqStabilizedIRK ─── v1.2.0
#    Installed OrdinaryDiffEqBDF ───────────── v1.2.0
#    Installed Wayland_jll ─────────────────── v1.21.0+2
#    Installed OrdinaryDiffEqDifferentiation ─ v1.3.0
#    Installed DifferentiationInterface ────── v0.6.28
#    Installed OpenSSL_jll ─────────────────── v3.0.15+2
#    Installed Xorg_libXfixes_jll ──────────── v6.0.0+0
#    Installed Xorg_libXrandr_jll ──────────── v1.5.4+0
#    Installed FilePathsBase ───────────────── v0.9.22
#    Installed Glib_jll ────────────────────── v2.82.4+0
#    Installed OrdinaryDiffEqIMEXMultistep ─── v1.2.0
#    Installed SparseDiffTools ─────────────── v2.23.1
#     Updating `C:\Users\Ivan\.julia\environments\v1.10\Project.toml`
#   [336ed68f] + CSV v0.10.15
#     Updating `C:\Users\Ivan\.julia\environments\v1.10\Manifest.toml`
#   [4fba245c] ↑ ArrayInterface v7.17.1 ⇒ v7.18.0
#   [aae01518] ↑ BandedMatrices v1.8.0 ⇒ v1.9.0
#   [336ed68f] + CSV v0.10.15
#   [7057c7e9] - Cassette v0.3.14
#   [944b1d66] + CodecZlib v0.7.6
#   [bcd4f6db] ↑ DelayDiffEq v5.49.0 ⇒ v5.51.0
#   [2b5f629d] ↑ DiffEqBase v6.160.0 ⇒ v6.161.0
#   [a0c0ee7d] ↑ DifferentiationInterface v0.6.27 ⇒ v0.6.28
#   [442a2c76] + FastGaussQuadrature v1.0.2
#   [48062228] + FilePathsBase v0.9.22
#   [f62d2435] - FunctionProperties v0.1.2
#   [28b8d3ca] ↑ GR v0.73.9 ⇒ v0.73.10
#   [842dd82b] + InlineStrings v1.4.2
#   [692b3bcd] ↑ JLLWrappers v1.6.1 ⇒ v1.7.0
#   [be0214bd] ↑ NonlinearSolveBase v1.3.3 ⇒ v1.4.0
#   [5959db7a] ↑ NonlinearSolveFirstOrder v1.1.0 ⇒ v1.2.0
#   [6fe1bfb0] ↑ OffsetArrays v1.14.2 ⇒ v1.15.0
#   [6ad6398a] ↑ OrdinaryDiffEqBDF v1.1.2 ⇒ v1.2.0
#   [bbf590c4] ↑ OrdinaryDiffEqCore v1.13.0 ⇒ v1.14.1
#   [4302a76b] ↑ OrdinaryDiffEqDifferentiation v1.2.0 ⇒ v1.3.0
#   [e0540318] ↑ OrdinaryDiffEqExponentialRK v1.1.0 ⇒ v1.2.0
#   [becaefa8] ↑ OrdinaryDiffEqExtrapolation v1.2.1 ⇒ v1.3.0
#   [5960d6e9] ↑ OrdinaryDiffEqFIRK v1.5.0 ⇒ v1.6.0
#   [9f002381] ↑ OrdinaryDiffEqIMEXMultistep v1.1.0 ⇒ v1.2.0
#   [5dd0a6cf] ↑ OrdinaryDiffEqPDIRK v1.1.0 ⇒ v1.2.0
#   [43230ef6] ↑ OrdinaryDiffEqRosenbrock v1.3.1 ⇒ v1.4.0
#   [2d112036] ↑ OrdinaryDiffEqSDIRK v1.1.0 ⇒ v1.2.0
#   [e3e12d00] ↑ OrdinaryDiffEqStabilizedIRK v1.1.0 ⇒ v1.2.0
#   [2dfb63ee] + PooledArrays v1.4.3
#   [0bca4576] ↑ SciMLBase v2.67.0 ⇒ v2.70.0
#   [91c51154] + SentinelArrays v1.4.8
#   [47a9eef4] ↑ SparseDiffTools v2.23.0 ⇒ v2.23.1
#   [90137ffa] ↑ StaticArrays v1.9.8 ⇒ v1.9.9
#   [2913bbd2] ↑ StatsBase v0.34.3 ⇒ v0.34.4
#   [789caeaf] ↑ StochasticDiffEq v6.72.0 ⇒ v6.72.1
#   [3bb67fe8] + TranscodingStreams v0.11.3
#   [ea10d353] + WeakRefStrings v1.4.2
#   [76eceee3] + WorkerUtilities v1.6.1
#   [6e34b625] ↑ Bzip2_jll v1.0.8+2 ⇒ v1.0.8+3
#   [2e619515] ↑ Expat_jll v2.6.4+1 ⇒ v2.6.4+2
#   [559328eb] ↑ FriBidi_jll v1.0.14+0 ⇒ v1.0.16+0
#   [0656b61e] ↑ GLFW_jll v3.4.0+1 ⇒ v3.4.0+2
#   [d2c73de3] ↑ GR_jll v0.73.9+0 ⇒ v0.73.10+0
#   [7746bdde] ↑ Glib_jll v2.82.2+1 ⇒ v2.82.4+0
#   [aacddb02] ↑ JpegTurbo_jll v3.0.4+0 ⇒ v3.1.0+1
#   [88015f11] ↑ LERC_jll v4.0.0+0 ⇒ v4.0.0+2
#   [dd4b983a] ↑ LZO_jll v2.10.2+1 ⇒ v2.10.2+2
# ⌅ [e9f186c6] ↑ Libffi_jll v3.2.2+1 ⇒ v3.2.2+2
#   [7add5ba3] ↑ Libgpg_error_jll v1.50.0+0 ⇒ v1.51.0+0
#   [4b2f31a3] ↑ Libmount_jll v2.40.2+0 ⇒ v2.40.2+1
#   [38a345b3] ↑ Libuuid_jll v2.40.2+0 ⇒ v2.40.2+1
#   [458c3c95] ↑ OpenSSL_jll v3.0.15+1 ⇒ v3.0.15+2
#   [efe28fd5] ↑ OpenSpecFun_jll v0.5.5+0 ⇒ v0.5.5+1
#   [36c8627f] ↑ Pango_jll v1.54.1+0 ⇒ v1.55.5+0
#   [a2964d1f] ↑ Wayland_jll v1.21.0+1 ⇒ v1.21.0+2
#   [2381bf8a] ↑ Wayland_protocols_jll v1.31.0+0 ⇒ v1.36.0+0
#   [ffd25f8a] ↑ XZ_jll v5.6.3+0 ⇒ v5.6.3+1
#   [935fb764] ↑ Xorg_libXcursor_jll v1.2.0+4 ⇒ v1.2.3+0
#   [d091e8ba] ↑ Xorg_libXfixes_jll v5.0.3+4 ⇒ v6.0.0+0
#   [a51aa0fd] ↑ Xorg_libXi_jll v1.7.10+4 ⇒ v1.8.2+0
#   [d1454406] ↑ Xorg_libXinerama_jll v1.1.4+4 ⇒ v1.1.5+0
#   [ec84b674] ↑ Xorg_libXrandr_jll v1.5.2+4 ⇒ v1.5.4+0
#   [ea2f1a96] ↑ Xorg_libXrender_jll v0.9.11+0 ⇒ v0.9.11+1
#   [cc61e674] ↑ Xorg_libxkbfile_jll v1.1.2+0 ⇒ v1.1.2+1
#   [35661453] ↑ Xorg_xkbcomp_jll v1.4.6+0 ⇒ v1.4.6+1
#   [3161d3a3] ↑ Zstd_jll v1.5.6+1 ⇒ v1.5.6+2
#   [b53b4c65] ↑ libpng_jll v1.6.44+0 ⇒ v1.6.44+1
#   [d8fb68d0] ↑ xkbcommon_jll v1.4.1+1 ⇒ v1.4.1+2
#         Info Packages marked with ⌅ have new versions available but compatibility constraints restrict them from upgrading. To see why use `status --outdated -m`
# Precompiling project...
#   ✓ WorkerUtilities
#   ✓ InlineStrings
#   ✓ TranscodingStreams
#   ✓ FilePathsBase
#   ✓ OffsetArrays
#   ✓ PooledArrays
#   ✓ JLLWrappers
#   ✓ DifferentiationInterface
#   ✓ SentinelArrays
#   ✓ InlineStrings → ParsersExt
#   ✓ CodecZlib
#   ✓ StatsBase
#   ✓ FilePathsBase → FilePathsBaseMmapExt
#   ✓ OffsetArrays → OffsetArraysAdaptExt
#   ✓ Libffi_jll
#   ✓ Wayland_protocols_jll
#   ✓ OpenSSL_jll
#   ✓ Libuuid_jll
#   ✓ OpenSpecFun_jll
#   ✓ JpegTurbo_jll
#   ✓ FriBidi_jll
#   ✓ libpng_jll
#   ✓ Zstd_jll
#   ✓ Expat_jll
#   ✓ LZO_jll
#   ✓ StaticArrays
#   ✓ Libmount_jll
#   ✓ Bzip2_jll
#   ✓ Libgpg_error_jll
#   ✓ DifferentiationInterface → DifferentiationInterfaceChainRulesCoreExt
#   ✓ LERC_jll
#   ✓ XZ_jll
#   ✓ DifferentiationInterface → DifferentiationInterfaceSparseArraysExt
#   ✓ WeakRefStrings
#   ✓ FilePathsBase → FilePathsBaseTestExt
#   ✓ Wayland_jll
#   ✓ Sparspak
#   ✓ StaticArrays → StaticArraysStatisticsExt
#   ✓ StaticArrays → StaticArraysChainRulesCoreExt
#   ✓ ConstructionBase → ConstructionBaseStaticArraysExt
#   ✓ Adapt → AdaptStaticArraysExt
#   ✓ DifferentiationInterface → DifferentiationInterfaceStaticArraysExt
#   ✓ LazyArrays → LazyArraysStaticArraysExt
#   ✓ FreeType2_jll
#   ✓ SpecialFunctions
#   ✓ Libgcrypt_jll
#   ✓ Libtiff_jll
#   ✓ DifferentiationInterface → DifferentiationInterfaceSparseMatrixColoringsExt
#   ✓ ResettableStacks
#   ✓ ArnoldiMethod
#   ✓ Glib_jll
#   ✓ BandedMatrices
#   ✓ Accessors → AccessorsStaticArraysExt
#   ✓ ArrayInterface
#   ✓ Fontconfig_jll
#   ✓ DomainSets
#   ✓ ColorVectorSpace → SpecialFunctionsExt
#   ✓ SpecialFunctions → SpecialFunctionsChainRulesCoreExt
#   ✓ SparseConnectivityTracer → SparseConnectivityTracerSpecialFunctionsExt
#   ✓ XSLT_jll
#   ✓ MarchingCubes
#   ✓ BandedMatrices → BandedMatricesSparseArraysExt
#   ✓ MatrixFactorizations → MatrixFactorizationsBandedMatricesExt
#   ✓ BlockArrays → BlockArraysBandedMatricesExt
#   ✓ ArrayInterface → ArrayInterfaceChainRulesCoreExt
#   ✓ ArrayInterface → ArrayInterfaceGPUArraysCoreExt
#   ✓ ArrayInterface → ArrayInterfaceSparseArraysExt
#   ✓ ArrayInterface → ArrayInterfaceBandedMatricesExt
#   ✓ ArrayInterface → ArrayInterfaceStaticArraysCoreExt
#   ✓ HypergeometricFunctions
#   ✓ LevyArea
#   ✓ Xorg_libXrender_jll
#   ✓ Xorg_libXfixes_jll
#   ✓ FastGaussQuadrature
#   ✓ Graphs
#   ✓ Xorg_libxkbfile_jll
#   ✓ Xorg_libXinerama_jll
#   ✓ SciMLStructures
#   ✓ ForwardDiff
#   ✓ MaybeInplace
#   ✓ LazyArrays → LazyArraysBandedMatricesExt
#   ✓ CSV
#   ✓ FiniteDiff
#   ✓ SymbolicIndexingInterface
#   ✓ StaticArrayInterface
#   ✓ SciMLOperators
#   ✓ Xorg_libXrandr_jll
#   ✓ Xorg_libXcursor_jll
#   ✓ Cairo_jll
#   ✓ Xorg_libXi_jll
#   ✓ Xorg_xkbcomp_jll
#   ✓ VertexSafeGraphs
#   ✓ ForwardDiff → ForwardDiffStaticArraysExt
#   ✓ FastPower → FastPowerForwardDiffExt
#   ✓ StatsFuns
#   ✓ MaybeInplace → MaybeInplaceSparseArraysExt
#   ✓ DifferentiationInterface → DifferentiationInterfaceForwardDiffExt
#   ✓ FiniteDiff → FiniteDiffSparseArraysExt
#   ✓ FiniteDiff → FiniteDiffStaticArraysExt
#   ✓ FiniteDiff → FiniteDiffBandedMatricesExt
#   ✓ DifferentiationInterface → DifferentiationInterfaceFiniteDiffExt
#   ✓ FastAlmostBandedMatrices
#   ✓ PlotlyJS → CSVExt
#   ✓ RecursiveArrayTools
#   ✓ StaticArrayInterface → StaticArrayInterfaceOffsetArraysExt
#   ✓ SciMLOperators → SciMLOperatorsStaticArraysCoreExt
#   ✓ StaticArrayInterface → StaticArrayInterfaceStaticArraysExt
#   ✓ SciMLOperators → SciMLOperatorsSparseArraysExt
#   ✓ Xorg_xkeyboard_config_jll
#   ✓ HarfBuzz_jll
#   ✓ PreallocationTools
#   ✓ StatsFuns → StatsFunsInverseFunctionsExt
#   ✓ StatsFuns → StatsFunsChainRulesCoreExt
#   ✓ NLSolversBase
#   ✓ CloseOpenIntervals
#   ✓ RecursiveArrayTools → RecursiveArrayToolsSparseArraysExt
#   ✓ LayoutPointers
#   ✓ xkbcommon_jll
#   ✓ libass_jll
#   ✓ Pango_jll
#   ✓ SparseDiffTools
#   ✓ ExponentialUtilities
#   ✓ LineSearches
#   ✓ RecursiveArrayTools → RecursiveArrayToolsForwardDiffExt
#   ✓ SymbolicUtils
#   ✓ StrideArraysCore
#   ✓ Distributions
#   ✓ GLFW_jll
#   ✓ ExponentialUtilities → ExponentialUtilitiesStaticArraysExt
#   ✓ VectorizationBase
#   ✓ Qt6Base_jll
#   ✓ FFMPEG_jll
#   ✓ NLsolve
#   ✓ Polyester
#   ✓ Optim
#   ✓ SymbolicLimits
#   ✓ Distributions → DistributionsChainRulesCoreExt
#   ✓ Distributions → DistributionsTestExt
#   ✓ SLEEFPirates
#   ✓ FFMPEG
#   ✓ FastBroadcast
#   ✓ Qt6ShaderTools_jll
#   ✓ GR_jll
#   ✓ RecursiveArrayTools → RecursiveArrayToolsFastBroadcastExt
#   ✓ SparseDiffTools → SparseDiffToolsPolyesterExt
#   ✓ Qt6Declarative_jll
#   ✓ UnicodePlots
#   ✓ UnicodePlots → UnitfulExt
#   ✓ UnicodePlots → IntervalSetsExt
#   ✓ GR
#   ✓ SciMLBase
#   ✓ SciMLBase → SciMLBaseChainRulesCoreExt
#   ✓ SciMLBase → SciMLBasePyCallExt
#   ✓ SCCNonlinearSolve
#   ✓ LoopVectorization
#   ✓ LoopVectorization → SpecialFunctionsExt
#   ✓ LoopVectorization → ForwardDiffExt
#   ✓ DiffEqBase
#   ✓ TriangularSolve
#   ✓ DiffEqBase → DiffEqBaseSparseArraysExt
#   ✓ DiffEqBase → DiffEqBaseChainRulesCoreExt
#   ✓ DiffEqBase → DiffEqBaseDistributionsExt
#   ✓ DiffEqBase → DiffEqBaseUnitfulExt
#   ✓ RecursiveFactorization
#   ✓ JumpProcesses
#   ✓ DiffEqNoiseProcess
#   ✓ Symbolics
#   ✓ OrdinaryDiffEqCore
#   ✓ Sundials
#   ✓ OrdinaryDiffEqCore → OrdinaryDiffEqCoreEnzymeCoreExt
#   ✓ DifferentiationInterface → DifferentiationInterfaceSymbolicsExt
#   ✓ Symbolics → SymbolicsForwardDiffExt
#   ✓ OrdinaryDiffEqExplicitRK
#   ✓ OrdinaryDiffEqStabilizedRK
#   ✓ OrdinaryDiffEqTsit5
#   ✓ OrdinaryDiffEqSSPRK
#   ✓ OrdinaryDiffEqLowStorageRK
#   ✓ OrdinaryDiffEqFunctionMap
#   ✓ OrdinaryDiffEqLowOrderRK
#   ✓ OrdinaryDiffEqQPRK
#   ✓ OrdinaryDiffEqHighOrderRK
#   ✓ OrdinaryDiffEqPRK
#   ✓ OrdinaryDiffEqRKN
#   ✓ Plots
#   ✓ LinearSolve
#   ✓ OrdinaryDiffEqSymplecticRK
#   ✓ OrdinaryDiffEqFeagin
#   ✓ SciMLJacobianOperators
#   ✓ DiffEqCallbacks
#   ✓ Symbolics → SymbolicsPreallocationToolsExt
#   ✓ SparseDiffTools → SparseDiffToolsSymbolicsExt
#   ✓ OrdinaryDiffEqNordsieck
#   ✓ OrdinaryDiffEqAdamsBashforthMoulton
#   ✓ LinearSolve → LinearSolveRecursiveArrayToolsExt
#   ✓ LineSearch
#   ✓ Plots → UnitfulExt
#   ✓ NonlinearSolveBase
#   ✓ SteadyStateDiffEq
#   ✓ LinearSolve → LinearSolveEnzymeExt
#   ✓ LineSearch → LineSearchLineSearchesExt
#   ✓ NonlinearSolveBase → NonlinearSolveBaseSparseArraysExt
#   ✓ LinearSolve → LinearSolveBandedMatricesExt
#   ✓ OrdinaryDiffEqVerner
#   ✓ NonlinearSolveBase → NonlinearSolveBaseSparseMatrixColoringsExt
#   ✓ NonlinearSolveBase → NonlinearSolveBaseForwardDiffExt
#   ✓ NonlinearSolveBase → NonlinearSolveBaseLineSearchExt
#   ✓ NonlinearSolveBase → NonlinearSolveBaseBandedMatricesExt
#   ✓ NonlinearSolveBase → NonlinearSolveBaseLinearSolveExt
#   ✓ OrdinaryDiffEqLinear
#   ✓ LinearSolve → LinearSolveFastAlmostBandedMatricesExt
#   ✓ NonlinearSolveBase → NonlinearSolveBaseDiffEqBaseExt
#   ✓ Plots → IJuliaExt
#   ✓ OrdinaryDiffEqDifferentiation
#   ✓ SimpleNonlinearSolve
#   ✓ SimpleNonlinearSolve → SimpleNonlinearSolveChainRulesCoreExt
#   ✓ OrdinaryDiffEqExtrapolation
#   ✓ NonlinearSolveFirstOrder
#   ✓ OrdinaryDiffEqRosenbrock
#   ✓ BoundaryValueDiffEqCore
#   ✓ NonlinearSolve
#   ✓ NonlinearSolve → NonlinearSolveNLsolveExt
#   ✓ NonlinearSolve → NonlinearSolveBandedMatricesExt
#   ✓ OrdinaryDiffEqNonlinearSolve
#   ✓ OrdinaryDiffEqStabilizedIRK
#   ✓ OrdinaryDiffEqPDIRK
#   ✓ OrdinaryDiffEqSDIRK
#   ✓ OrdinaryDiffEqIMEXMultistep
#   ✓ OrdinaryDiffEqFIRK
#   ✓ OrdinaryDiffEqExponentialRK
#   ✓ OrdinaryDiffEqBDF
#   ✓ BoundaryValueDiffEqMIRK
#   ✓ BoundaryValueDiffEqFIRK
#   ✓ OrdinaryDiffEqDefault
#   ✓ ModelingToolkit
#   ✓ OrdinaryDiffEq
#   ✓ ModelingToolkit → MTKChainRulesCoreExt
#   ✓ DelayDiffEq
#   ✓ BoundaryValueDiffEqShooting
#   ✓ StochasticDiffEq
#   ✓ ParameterizedFunctions
#   ✓ BoundaryValueDiffEq
#   ✓ DifferentialEquations
#   242 dependencies successfully precompiled in 519 seconds. 272 already precompiled.
#   1 dependency precompiled but a different version is currently loaded. Restart julia to access the new version
#    Resolving package versions...
#    Installed InvertedIndices ──── v1.3.1
#    Installed StringManipulation ─ v0.4.0
#    Installed PrettyTables ─────── v2.4.0
#    Installed DataFrames ───────── v1.7.0
#     Updating `C:\Users\Ivan\.julia\environments\v1.10\Project.toml`
#   [a93c6f00] + DataFrames v1.7.0
#     Updating `C:\Users\Ivan\.julia\environments\v1.10\Manifest.toml`
#   [a93c6f00] + DataFrames v1.7.0
#   [41ab1584] + InvertedIndices v1.3.1
#   [08abe8d2] + PrettyTables v2.4.0
#   [892a3eda] + StringManipulation v0.4.0
# Precompiling project...
#   ✓ InvertedIndices
#   ✓ StringManipulation
#   ✓ PlotlyJS → IJuliaExt
#   ✓ PrettyTables
#   ✓ DataFrames
#   ✓ Latexify → DataFramesExt
#   ✓ PlotlyJS → DataFramesExt
#   ✓ Plotly
#   8 dependencies successfully precompiled in 70 seconds. 512 already precompiled.
#    Resolving package versions...
#    Installed Mocking ─────────── v0.8.1
#    Installed TZJData ─────────── v1.3.1+2024b
#    Installed RData ───────────── v0.8.3
#    Installed CategoricalArrays ─ v0.10.8
#    Installed TimeZones ───────── v1.20.0
#    Installed FileIO ──────────── v1.16.5
#    Installed RDatasets ───────── v0.7.7
#     Updating `C:\Users\Ivan\.julia\environments\v1.10\Project.toml`
#   [ce6b1742] + RDatasets v0.7.7
#     Updating `C:\Users\Ivan\.julia\environments\v1.10\Manifest.toml`
#   [324d7699] + CategoricalArrays v0.10.8
# ⌃ [5789e2e9] + FileIO v1.16.5
#   [78c3b35d] + Mocking v0.8.1
# ⌅ [df47a6cb] + RData v0.8.3
#   [ce6b1742] + RDatasets v0.7.7
#   [dc5dba14] + TZJData v1.3.1+2024b
#   [f269a46b] + TimeZones v1.20.0
#         Info Packages marked with ⌃ and ⌅ have new versions available. Those with ⌃ may be upgradable, but those with ⌅ are restricted by compatibility constraints from upgrading. To see why use `status --outdated -m`
# Precompiling project...
#   ✓ Mocking
#   ✓ TZJData
#   ✓ CategoricalArrays
#   ✓ FileIO
#   ✓ CategoricalArrays → CategoricalArraysSentinelArraysExt
#   ✓ CategoricalArrays → CategoricalArraysRecipesBaseExt
#   ✓ CategoricalArrays → CategoricalArraysJSONExt
#   ✓ Plots → FileIOExt
#   ✓ TimeZones
#   ✓ TimeZones → TimeZonesRecipesBaseExt
#   ✓ RData
#   ✓ RDatasets
#   12 dependencies successfully precompiled in 25 seconds. 520 already precompiled.
#    Resolving package versions...
#     Updating `C:\Users\Ivan\.julia\environments\v1.10\Project.toml`
# ⌃ [5789e2e9] + FileIO v1.16.5
#   No Changes to `C:\Users\Ivan\.julia\environments\v1.10\Manifest.toml`

# %%
# Считывание данных и их запись в структуру:
P = CSV.File("programminglanguages.csv") |> DataFrame
# Функция определения по названию языка программирования года его создания:
function language_created_year(P,language::String)
    loc = findfirst(P[:,2].==language)
    return P[loc,1]
end
# Пример вызова функции и определение даты создания языка Python:
language_created_year(P,"Python")
# Out:
# 1991

# %%
# Пример вызова функции и определение даты создания языка Julia:
language_created_year(P,"Julia")
# Out:
# 2012

# %%
language_created_year(P,"julia")
# Out:
# MethodError: no method matching getindex(::DataFrame, ::Nothing, ::Int64)
#
# Closest candidates are:
#   getindex(::DataFrame, ::typeof(!), ::Union{Signed, Unsigned})
#    @ DataFrames C:\Users\Ivan\.julia\packages\DataFrames\kcA9R\src\dataframe\dataframe.jl:548
#   getindex(::DataFrame, ::Colon, ::Union{AbstractString, Signed, Symbol, Unsigned})
#    @ DataFrames C:\Users\Ivan\.julia\packages\DataFrames\kcA9R\src\dataframe\dataframe.jl:542
#   getindex(::DataFrame, ::Integer, ::Union{Signed, Unsigned})
#    @ DataFrames C:\Users\Ivan\.julia\packages\DataFrames\kcA9R\src\dataframe\dataframe.jl:506
#   ...
#
#
# Stacktrace:
#  [1] language_created_year(P::DataFrame, language::String)
#    @ Main .\In[61]:6
#  [2] top-level scope
#    @ In[63]:1

# %%
# Функция определения по названию языка программирования
# года его создания (без учёта регистра):
function language_created_year_v2(P,language::String)
    loc = findfirst(lowercase.(P[:,2]).==lowercase.(language))
    return P[loc,1]
end
# Пример вызова функции и определение даты создания языка julia:
language_created_year_v2(P,"julia")
# Out:
# 2012

# %%
# Построчное считывание данных с указанием разделителя:
Tx = readdlm("programminglanguages.csv", ',')
# Out:
# 74×2 Matrix{Any}:
#      "year"  "language"
#  1951        "Regional Assembly Language"
#  1952        "Autocode"
#  1954        "IPL"
#  1955        "FLOW-MATIC"
#  1957        "FORTRAN"
#  1957        "COMTRAN"
#  1958        "LISP"
#  1958        "ALGOL 58"
#  1959        "FACT"
#  1959        "COBOL"
#  1959        "RPG"
#  1962        "APL"
#     ⋮
#  2003        "Scala"
#  2005        "F#"
#  2006        "PowerShell"
#  2007        "Clojure"
#  2009        "Go"
#  2010        "Rust"
#  2011        "Dart"
#  2011        "Kotlin"
#  2011        "Red"
#  2011        "Elixir"
#  2012        "Julia"
#  2014        "Swift"

# %% [markdown]
# #### 1.2. Запись данных в файл

# %%
# Запись данных в CSV-файл:
CSV.write("programming_languages_data2.csv", P)
# Out:
# "programming_languages_data2.csv"

# %%
# Пример записи данных в текстовый файл с разделителем ',':
writedlm("programming_languages_data.txt", Tx, ',')

# %%
# Пример записи данных в текстовый файл с разделителем '-':
writedlm("programming_languages_data2.txt", Tx, '-')

# %%
# Построчное считывание данных с указанием разделителя:
P_new_delim = readdlm("programming_languages_data2.txt", '-')
# Out:
# 74×2 Matrix{Any}:
#      "year"  "language"
#  1951        "Regional Assembly Language"
#  1952        "Autocode"
#  1954        "IPL"
#  1955        "FLOW-MATIC"
#  1957        "FORTRAN"
#  1957        "COMTRAN"
#  1958        "LISP"
#  1958        "ALGOL 58"
#  1959        "FACT"
#  1959        "COBOL"
#  1959        "RPG"
#  1962        "APL"
#     ⋮
#  2003        "Scala"
#  2005        "F#"
#  2006        "PowerShell"
#  2007        "Clojure"
#  2009        "Go"
#  2010        "Rust"
#  2011        "Dart"
#  2011        "Kotlin"
#  2011        "Red"
#  2011        "Elixir"
#  2012        "Julia"
#  2014        "Swift"

# %% [markdown]
# #### 1.3. Словари

# %%
# Инициализация словаря:
dict = Dict{Integer,Vector{String}}()
# Out:
# Dict{Integer, Vector{String}}()

# %%
# Инициализация словаря:
dict2 = Dict()
# Out:
# Dict{Any, Any}()

# %%
# Заполнение словаря данными:
for i = 1:size(P,1)
    year,lang = P[i,:]
    if year in keys(dict)
        dict[year] = push!(dict[year],lang)
    else
        dict[year] = [lang]
    end
end

# %%
# Пример определения в словаре языков программирования, созданных в 2003 году:
dict[2003]
# Out:
# 2-element Vector{String}:
#  "Groovy"
#  "Scala"

# %% [markdown]
# #### 1.4. DataFrames

# %%
# Подгружаем пакет DataFrames:
using DataFrames

# %%
# Задаём переменную со структурой DataFrame:
df = DataFrame(year = P[:,1], language = P[:,2])
# Вывод всех значения столбца year:
df[!,:year]
# Получение статистических сведений о фрейме:
describe(df)
# Out:
# 2×7 DataFrame
#  Row │ variable  mean     min       median  max        nmissing  eltype
#      │ Symbol    Union…   Any       Union…  Any        Int64     DataType
# ─────┼────────────────────────────────────────────────────────────────────
#    1 │ year      1982.99  1951      1986.0  2014              0  Int64
#    2 │ language           ALGOL 58          dBase III         0  String31

# %% [markdown]
# #### 1.5. RDatasets

# %%
# Подгружаем пакет RDatasets:
using RDatasets

# %%
# Задаём структуру данных в виде набора данных:
iris = dataset("datasets", "iris")
# Определения типа переменной:
typeof(iris)
# Out:
# DataFrame

# %%
describe(iris)
# Out:
# 5×7 DataFrame
#  Row │ variable     mean     min     median  max        nmissing  eltype       ⋯
#      │ Symbol       Union…   Any     Union…  Any        Int64     DataType     ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ SepalLength  5.84333  4.3     5.8     7.9               0  Float64      ⋯
#    2 │ SepalWidth   3.05733  2.0     3.0     4.4               0  Float64
#    3 │ PetalLength  3.758    1.0     4.35    6.9               0  Float64
#    4 │ PetalWidth   1.19933  0.1     1.3     2.5               0  Float64
#    5 │ Species               setosa          virginica         0  CategoricalV ⋯
#                                                                 1 column omitted

# %% [markdown]
# #### 1.6. Работа с переменными отсутствующего типа (Missing Values)

# %%
# Отсутствующий тип:
a = missing
typeof(a)
# Out:
# Missing

# %%
# Пример операции с переменной отсутствующего типа:
a + 1
# Out:
# missing

# %%
# Определение перечня продуктов:
foods = ["apple", "cucumber", "tomato", "banana"]
# Определение калорий:
calories = [missing,47,22,105]
# Определение типа переменной:
typeof(calories)
# Out:
# Vector{Union{Missing, Int64}} (alias for Array{Union{Missing, Int64}, 1})

# %%
# Подключаем пакет Statistics:
using Statistics
# Определение среднего значения:
mean(calories)
# Определение среднего значения без значений с отсутствующим типом:
mean(skipmissing(calories))
# Out:
# 58.0

# %%
# Задание сведений о ценах:
prices = [0.85,1.6,0.8,0.6]
# Формирование данных о калориях:
dataframe_calories = DataFrame(item=foods,calories=calories)
# Формирование данных о ценах:
dataframe_prices = DataFrame(item=foods,price=prices)
# Объединение данных о калориях и ценах:
DF = innerjoin(dataframe_calories,dataframe_prices,on=:item)
# Out:
# 4×3 DataFrame
#  Row │ item      calories  price
#      │ String    Int64?    Float64
# ─────┼─────────────────────────────
#    1 │ apple      missing     0.85
#    2 │ cucumber        47     1.6
#    3 │ tomato          22     0.8
#    4 │ banana         105     0.6

# %% [markdown]
# #### 1.7. FileIO

# %%
# Подключаем пакет FileIO:
using FileIO

# %%
# Подключаем пакет ImageIO:
import Pkg
Pkg.add("ImageIO")
# Out:
#    Resolving package versions...
#    Installed PNGFiles ─────── v0.4.3
#    Installed ImageIO ──────── v0.6.9
#    Installed ProgressMeter ── v1.10.2
#    Installed JpegTurbo ────── v0.1.5
#    Installed AxisArrays ───── v0.4.7
#    Installed OpenEXR ──────── v0.3.3
#    Installed Sixel ────────── v0.1.3
#    Installed TiffImages ───── v0.11.2
#    Installed Netpbm ───────── v1.1.1
#    Installed Giflib_jll ───── v5.2.2+1
#    Installed SIMD ─────────── v3.7.0
#    Installed PkgVersion ───── v0.3.3
#    Installed QOI ──────────── v1.0.1
#    Installed WebP ─────────── v0.1.3
#    Installed ImageMetadata ── v0.9.10
#    Installed MappedArrays ─── v0.4.2
#    Installed PaddedViews ──── v0.5.12
#    Installed LazyModules ──── v0.3.1
#    Installed MosaicViews ──── v0.3.4
#    Installed OpenEXR_jll ──── v3.2.4+0
#    Installed Imath_jll ────── v3.1.11+0
#    Installed StackViews ───── v0.1.1
#    Installed RangeArrays ──── v0.3.2
#    Installed ImageBase ────── v0.1.7
#    Installed IterTools ────── v1.10.0
#    Installed ImageCore ────── v0.10.5
#    Installed IndirectArrays ─ v1.0.0
#    Installed libsixel_jll ─── v1.10.3+2
#    Installed libwebp_jll ──── v1.4.0+0
#    Installed ImageAxes ────── v0.6.12
#     Updating `C:\Users\Ivan\.julia\environments\v1.10\Project.toml`
#   [82e4d734] + ImageIO v0.6.9
#     Updating `C:\Users\Ivan\.julia\environments\v1.10\Manifest.toml`
#   [39de3d68] + AxisArrays v0.4.7
#   [2803e5a7] + ImageAxes v0.6.12
#   [c817782e] + ImageBase v0.1.7
#   [a09fc81d] + ImageCore v0.10.5
#   [82e4d734] + ImageIO v0.6.9
#   [bc367c6b] + ImageMetadata v0.9.10
#   [9b13fd28] + IndirectArrays v1.0.0
#   [c8e1da08] + IterTools v1.10.0
#   [b835a17e] + JpegTurbo v0.1.5
#   [8cdb02fc] + LazyModules v0.3.1
#   [dbb5928d] + MappedArrays v0.4.2
#   [e94cdb99] + MosaicViews v0.3.4
#   [f09324ee] + Netpbm v1.1.1
#   [52e1d378] + OpenEXR v0.3.3
#   [f57f5aa1] + PNGFiles v0.4.3
#   [5432bcbf] + PaddedViews v0.5.12
#   [eebad327] + PkgVersion v0.3.3
#   [92933f4c] + ProgressMeter v1.10.2
#   [4b34888f] + QOI v1.0.1
#   [b3c3ace0] + RangeArrays v0.3.2
#   [fdea26ae] + SIMD v3.7.0
#   [45858cf5] + Sixel v0.1.3
#   [cae243ae] + StackViews v0.1.1
#   [731e570b] + TiffImages v0.11.2
#   [e3aaa7dc] + WebP v0.1.3
#   [59f7168a] + Giflib_jll v5.2.2+1
#   [905a6f67] + Imath_jll v3.1.11+0
#   [18a262bb] + OpenEXR_jll v3.2.4+0
#   [075b6546] + libsixel_jll v1.10.3+2
#   [c5f90fcd] + libwebp_jll v1.4.0+0
# Precompiling project...
#   ✓ LazyModules
#   ✓ IndirectArrays
#   ✓ RangeArrays
#   ✓ MappedArrays
#   ✓ IterTools
#   ✓ Imath_jll
#   ✓ ProgressMeter
#   ✓ Giflib_jll
#   ✓ PkgVersion
#   ✓ PaddedViews
#   ✓ StackViews
#   ✓ libsixel_jll
#   ✓ OpenEXR_jll
#   ✓ libwebp_jll
#   ✓ QOI
#   ✓ AxisArrays
#   ✓ MosaicViews
#   ✓ OpenEXR
#   ✓ SIMD
#   ✓ ImageCore
#   ✓ WebP
#   ✓ Sixel
#   ✓ ImageBase
#   ✓ JpegTurbo
#   ✓ PNGFiles
#   ✓ ImageAxes
#   ✓ ImageMetadata
#   ✓ Netpbm
#   ✓ TiffImages
#   ✓ ImageIO
#   30 dependencies successfully precompiled in 87 seconds. 532 already precompiled.

# %%
X1 = load("julialogo.png")
display(X1)
# Out:
# [ Info: Precompiling PNGFiles [f57f5aa1-a3ce-4bc8-8ab9-96f992907883]
# ERROR: LoadError: ArgumentError: Platform `riscv64-linux-gnu-libgfortran5` is not an officially supported platform
# Stacktrace:
#  [1] parse(::Type{Base.BinaryPlatforms.Platform}, triplet::String; validate_strict::Bool)
#    @ Base.BinaryPlatforms .\binaryplatforms.jl:753
#  [2] parse(::Type{Base.BinaryPlatforms.Platform}, triplet::String)
#    @ Base.BinaryPlatforms .\binaryplatforms.jl:671
#  [3] (::OpenSpecFun_jll.var"#parse_wrapper_platform#1")(x::Any)
#    @ OpenSpecFun_jll C:\Users\Ivan\.julia\packages\JLLWrappers\jXOYx\src\toplevel_generators.jl:113
#  [4] (::OpenSpecFun_jll.var"#make_wrapper_dict#2"{OpenSpecFun_jll.var"#parse_wrapper_platform#1"})(dir::Any, x::Any)
#    @ OpenSpecFun_jll C:\Users\Ivan\.julia\packages\JLLWrappers\jXOYx\src\toplevel_generators.jl:145
#  [5] top-level scope
#    @ C:\Users\Ivan\.julia\packages\JLLWrappers\jXOYx\src\toplevel_generators.jl:160
#  [6] include
#    @ .\Base.jl:495 [inlined]
#  [7] include_package_for_output(pkg::Base.PkgId, input::String, depot_path::Vector{String}, dl_load_path::Vector{String}, load_path::Vector{String}, concrete_deps::Vector{Pair{Base.PkgId, UInt128}}, source::String)
#    @ Base .\loading.jl:2222
#  [8] top-level scope
#    @ stdin:3
# in expression starting at C:\Users\Ivan\.julia\packages\OpenSpecFun_jll\xV9iu\src\OpenSpecFun_jll.jl:2
# in expression starting at stdin:3
# ERROR: LoadError: Failed to precompile OpenSpecFun_jll [efe28fd5-8261-553b-a9e1-b2916fc3738e] to "C:\\Users\\Ivan\\.julia\\compiled\\v1.10\\OpenSpecFun_jll\\jl_8131.tmp".
# Stacktrace:
#   [1] error(s::String)
#     @ Base .\error.jl:35
#   [2] compilecache(pkg::Base.PkgId, path::String, internal_stderr::IO, internal_stdout::IO, keep_loaded_modules::Bool)
#     @ Base .\loading.jl:2468
#   [3] compilecache
#     @ .\loading.jl:2340 [inlined]
#   [4] (::Base.var"#968#969"{Base.PkgId})()
#     @ Base .\loading.jl:1974
#   [5] mkpidlock(f::Base.var"#968#969"{Base.PkgId}, at::String, pid::Int32; kwopts::@Kwargs{stale_age::Int64, wait::Bool})
#     @ FileWatching.Pidfile c:\users\ivan\appdata\local\programs\julia-1.10.5\share\julia\stdlib\v1.10\FileWatching\src\pidfile.jl:93
#   [6] #mkpidlock#6
#     @ c:\users\ivan\appdata\local\programs\julia-1.10.5\share\julia\stdlib\v1.10\FileWatching\src\pidfile.jl:88 [inlined]
#   [7] trymkpidlock(::Function, ::Vararg{Any}; kwargs::@Kwargs{stale_age::Int64})
#     @ FileWatching.Pidfile c:\users\ivan\appdata\local\programs\julia-1.10.5\share\julia\stdlib\v1.10\FileWatching\src\pidfile.jl:111
#   [8] #invokelatest#2
#     @ .\essentials.jl:894 [inlined]
#   [9] invokelatest
#     @ .\essentials.jl:889 [inlined]
#  [10] maybe_cachefile_lock(f::Base.var"#968#969"{Base.PkgId}, pkg::Base.PkgId, srcpath::String; stale_age::Int64)
#     @ Base .\loading.jl:2983
#  [11] maybe_cachefile_lock
#     @ .\loading.jl:2980 [inlined]
#  [12] _require(pkg::Base.PkgId, env::String)
#     @ Base .\loading.jl:1970
#  [13] __require_prelocked(uuidkey::Base.PkgId, env::String)
#     @ Base .\loading.jl:1812
#  [14] #invoke_in_world#3
#     @ .\essentials.jl:926 [inlined]
#  [15] invoke_in_world
#     @ .\essentials.jl:923 [inlined]
#  [16] _require_prelocked(uuidkey::Base.PkgId, env::String)
#     @ Base .\loading.jl:1803
#  [17] macro expansion
#     @ .\loading.jl:1790 [inlined]
#  [18] macro expansion
#     @ .\lock.jl:267 [inlined]
#  [19] __require(into::Module, mod::Symbol)
#     @ Base .\loading.jl:1753
#  [20] #invoke_in_world#3
#     @ .\essentials.jl:926 [inlined]
#  [21] invoke_in_world
#     @ .\essentials.jl:923 [inlined]
#  [22] require(into::Module, mod::Symbol)
#     @ Base .\loading.jl:1746
#  [23] include
#     @ .\Base.jl:495 [inlined]
#  [24] include_package_for_output(pkg::Base.PkgId, input::String, depot_path::Vector{String}, dl_load_path::Vector{String}, load_path::Vector{String}, concrete_deps::Vector{Pair{Base.PkgId, UInt128}}, source::String)
#     @ Base .\loading.jl:2222
#  [25] top-level scope
#     @ stdin:3
# in expression starting at C:\Users\Ivan\.julia\packages\SpecialFunctions\Zijv9\src\SpecialFunctions.jl:1
# in expression starting at stdin:3
# ERROR: LoadError: Failed to precompile SpecialFunctions [276daf66-3868-5448-9aa4-cd146d93841b] to "C:\\Users\\Ivan\\.julia\\compiled\\v1.10\\SpecialFunctions\\jl_7FDA.tmp".
# Stacktrace:
#   [1] error(s::String)
#     @ Base .\error.jl:35
#   [2] compilecache(pkg::Base.PkgId, path::String, internal_stderr::IO, internal_stdout::IO, keep_loaded_modules::Bool)
#     @ Base .\loading.jl:2468
#   [3] compilecache
#     @ .\loading.jl:2340 [inlined]
#   [4] (::Base.var"#968#969"{Base.PkgId})()
#     @ Base .\loading.jl:1974
#   [5] mkpidlock(f::Base.var"#968#969"{Base.PkgId}, at::String, pid::Int32; kwopts::@Kwargs{stale_age::Int64, wait::Bool})
#     @ FileWatching.Pidfile c:\users\ivan\appdata\local\programs\julia-1.10.5\share\julia\stdlib\v1.10\FileWatching\src\pidfile.jl:93
#   [6] #mkpidlock#6
#     @ c:\users\ivan\appdata\local\programs\julia-1.10.5\share\julia\stdlib\v1.10\FileWatching\src\pidfile.jl:88 [inlined]
#   [7] trymkpidlock(::Function, ::Vararg{Any}; kwargs::@Kwargs{stale_age::Int64})
#     @ FileWatching.Pidfile c:\users\ivan\appdata\local\programs\julia-1.10.5\share\julia\stdlib\v1.10\FileWatching\src\pidfile.jl:111
#   [8] #invokelatest#2
#     @ .\essentials.jl:894 [inlined]
#   [9] invokelatest
#     @ .\essentials.jl:889 [inlined]
#  [10] maybe_cachefile_lock(f::Base.var"#968#969"{Base.PkgId}, pkg::Base.PkgId, srcpath::String; stale_age::Int64)
#     @ Base .\loading.jl:2983
#  [11] maybe_cachefile_lock
#     @ .\loading.jl:2980 [inlined]
#  [12] _require(pkg::Base.PkgId, env::String)
#     @ Base .\loading.jl:1970
#  [13] __require_prelocked(uuidkey::Base.PkgId, env::String)
#     @ Base .\loading.jl:1812
#  [14] #invoke_in_world#3
#     @ .\essentials.jl:926 [inlined]
#  [15] invoke_in_world
#     @ .\essentials.jl:923 [inlined]
#  [16] _require_prelocked(uuidkey::Base.PkgId, env::String)
#     @ Base .\loading.jl:1803
#  [17] macro expansion
#     @ .\loading.jl:1790 [inlined]
#  [18] macro expansion
#     @ .\lock.jl:267 [inlined]
#  [19] __require(into::Module, mod::Symbol)
#     @ Base .\loading.jl:1753
#  [20] #invoke_in_world#3
#     @ .\essentials.jl:926 [inlined]
#  [21] invoke_in_world
#     @ .\essentials.jl:923 [inlined]
#  [22] require(into::Module, mod::Symbol)
#     @ Base .\loading.jl:1746
#  [23] include
#     @ .\Base.jl:495 [inlined]
#  [24] include_package_for_output(pkg::Base.PkgId, input::String, depot_path::Vector{String}, dl_load_path::Vector{String}, load_path::Vector{String}, concrete_deps::Vector{Pair{Base.PkgId, UInt128}}, source::String)
#     @ Base .\loading.jl:2222
#  [25] top-level scope
#     @ stdin:3
# in expression starting at C:\Users\Ivan\.julia\packages\ColorVectorSpace\QI5vM\src\ColorVectorSpace.jl:1
# in expression starting at stdin:3
# ERROR: LoadError: Failed to precompile ColorVectorSpace [c3611d14-8923-5661-9e6a-0046d554d3a4] to "C:\\Users\\Ivan\\.julia\\compiled\\v1.10\\ColorVectorSpace\\jl_7DB7.tmp".
# Stacktrace:
#   [1] error(s::String)
#     @ Base .\error.jl:35
#   [2] compilecache(pkg::Base.PkgId, path::String, internal_stderr::IO, internal_stdout::IO, keep_loaded_modules::Bool)
#     @ Base .\loading.jl:2468
#   [3] compilecache
#     @ .\loading.jl:2340 [inlined]
#   [4] (::Base.var"#968#969"{Base.PkgId})()
#     @ Base .\loading.jl:1974
#   [5] mkpidlock(f::Base.var"#968#969"{Base.PkgId}, at::String, pid::Int32; kwopts::@Kwargs{stale_age::Int64, wait::Bool})
#     @ FileWatching.Pidfile c:\users\ivan\appdata\local\programs\julia-1.10.5\share\julia\stdlib\v1.10\FileWatching\src\pidfile.jl:93
#   [6] #mkpidlock#6
#     @ c:\users\ivan\appdata\local\programs\julia-1.10.5\share\julia\stdlib\v1.10\FileWatching\src\pidfile.jl:88 [inlined]
#   [7] trymkpidlock(::Function, ::Vararg{Any}; kwargs::@Kwargs{stale_age::Int64})
#     @ FileWatching.Pidfile c:\users\ivan\appdata\local\programs\julia-1.10.5\share\julia\stdlib\v1.10\FileWatching\src\pidfile.jl:111
#   [8] #invokelatest#2
#     @ .\essentials.jl:894 [inlined]
#   [9] invokelatest
#     @ .\essentials.jl:889 [inlined]
#  [10] maybe_cachefile_lock(f::Base.var"#968#969"{Base.PkgId}, pkg::Base.PkgId, srcpath::String; stale_age::Int64)
#     @ Base .\loading.jl:2983
#  [11] maybe_cachefile_lock
#     @ .\loading.jl:2980 [inlined]
#  [12] _require(pkg::Base.PkgId, env::String)
#     @ Base .\loading.jl:1970
#  [13] __require_prelocked(uuidkey::Base.PkgId, env::String)
#     @ Base .\loading.jl:1812
#  [14] #invoke_in_world#3
#     @ .\essentials.jl:926 [inlined]
#  [15] invoke_in_world
#     @ .\essentials.jl:923 [inlined]
#  [16] _require_prelocked(uuidkey::Base.PkgId, env::String)
#     @ Base .\loading.jl:1803
#  [17] macro expansion
#     @ .\loading.jl:1790 [inlined]
#  [18] macro expansion
#     @ .\lock.jl:267 [inlined]
#  [19] __require(into::Module, mod::Symbol)
#     @ Base .\loading.jl:1753
#  [20] #invoke_in_world#3
#     @ .\essentials.jl:926 [inlined]
#  [21] invoke_in_world
#     @ .\essentials.jl:923 [inlined]
#  [22] require(into::Module, mod::Symbol)
#     @ Base .\loading.jl:1746
#  [23] include
#     @ .\Base.jl:495 [inlined]
#  [24] include_package_for_output(pkg::Base.PkgId, input::String, depot_path::Vector{String}, dl_load_path::Vector{String}, load_path::Vector{String}, concrete_deps::Vector{Pair{Base.PkgId, UInt128}}, source::String)
#     @ Base .\loading.jl:2222
#  [25] top-level scope
#     @ stdin:3
# in expression starting at C:\Users\Ivan\.julia\packages\ImageCore\wTsMr\src\ImageCore.jl:1
# in expression starting at stdin:3
# ERROR: LoadError: Failed to precompile ImageCore [a09fc81d-aa75-5fe9-8630-4744c3626534] to "C:\\Users\\Ivan\\.julia\\compiled\\v1.10\\ImageCore\\jl_79A0.tmp".
# Stacktrace:
#   [1] error(s::String)
#     @ Base .\error.jl:35
#   [2] compilecache(pkg::Base.PkgId, path::String, internal_stderr::IO, internal_stdout::IO, keep_loaded_modules::Bool)
#     @ Base .\loading.jl:2468
#   [3] compilecache
#     @ .\loading.jl:2340 [inlined]
#   [4] (::Base.var"#968#969"{Base.PkgId})()
#     @ Base .\loading.jl:1974
#   [5] mkpidlock(f::Base.var"#968#969"{Base.PkgId}, at::String, pid::Int32; kwopts::@Kwargs{stale_age::Int64, wait::Bool})
#     @ FileWatching.Pidfile c:\users\ivan\appdata\local\programs\julia-1.10.5\share\julia\stdlib\v1.10\FileWatching\src\pidfile.jl:93
#   [6] #mkpidlock#6
#     @ c:\users\ivan\appdata\local\programs\julia-1.10.5\share\julia\stdlib\v1.10\FileWatching\src\pidfile.jl:88 [inlined]
#   [7] trymkpidlock(::Function, ::Vararg{Any}; kwargs::@Kwargs{stale_age::Int64})
#     @ FileWatching.Pidfile c:\users\ivan\appdata\local\programs\julia-1.10.5\share\julia\stdlib\v1.10\FileWatching\src\pidfile.jl:111
#   [8] #invokelatest#2
#     @ .\essentials.jl:894 [inlined]
#   [9] invokelatest
#     @ .\essentials.jl:889 [inlined]
#  [10] maybe_cachefile_lock(f::Base.var"#968#969"{Base.PkgId}, pkg::Base.PkgId, srcpath::String; stale_age::Int64)
#     @ Base .\loading.jl:2983
#  [11] maybe_cachefile_lock
#     @ .\loading.jl:2980 [inlined]
#  [12] _require(pkg::Base.PkgId, env::String)
#     @ Base .\loading.jl:1970
#  [13] __require_prelocked(uuidkey::Base.PkgId, env::String)
#     @ Base .\loading.jl:1812
#  [14] #invoke_in_world#3
#     @ .\essentials.jl:926 [inlined]
#  [15] invoke_in_world
#     @ .\essentials.jl:923 [inlined]
#  [16] _require_prelocked(uuidkey::Base.PkgId, env::String)
#     @ Base .\loading.jl:1803
#  [17] macro expansion
#     @ .\loading.jl:1790 [inlined]
#  [18] macro expansion
#     @ .\lock.jl:267 [inlined]
#  [19] __require(into::Module, mod::Symbol)
#     @ Base .\loading.jl:1753
#  [20] #invoke_in_world#3
#     @ .\essentials.jl:926 [inlined]
#  [21] invoke_in_world
#     @ .\essentials.jl:923 [inlined]
#  [22] require(into::Module, mod::Symbol)
#     @ Base .\loading.jl:1746
#  [23] include
#     @ .\Base.jl:495 [inlined]
#  [24] include_package_for_output(pkg::Base.PkgId, input::String, depot_path::Vector{String}, dl_load_path::Vector{String}, load_path::Vector{String}, concrete_deps::Vector{Pair{Base.PkgId, UInt128}}, source::Nothing)
#     @ Base .\loading.jl:2222
#  [25] top-level scope
#     @ stdin:3
# in expression starting at C:\Users\Ivan\.julia\packages\PNGFiles\CBHvB\src\PNGFiles.jl:1
# in expression starting at stdin:3
# [ Info: Precompiling ImageMagick [6218d12a-5da1-5696-b52f-db25d2ecc6d1]
# ERROR: LoadError: ArgumentError: Platform `riscv64-linux-gnu-libgfortran5` is not an officially supported platform
# Stacktrace:
#  [1] parse(::Type{Base.BinaryPlatforms.Platform}, triplet::String; validate_strict::Bool)
#    @ Base.BinaryPlatforms .\binaryplatforms.jl:753
#  [2] parse(::Type{Base.BinaryPlatforms.Platform}, triplet::String)
#    @ Base.BinaryPlatforms .\binaryplatforms.jl:671
#  [3] (::OpenSpecFun_jll.var"#parse_wrapper_platform#1")(x::Any)
#    @ OpenSpecFun_jll C:\Users\Ivan\.julia\packages\JLLWrappers\jXOYx\src\toplevel_generators.jl:113
#  [4] (::OpenSpecFun_jll.var"#make_wrapper_dict#2"{OpenSpecFun_jll.var"#parse_wrapper_platform#1"})(dir::Any, x::Any)
#    @ OpenSpecFun_jll C:\Users\Ivan\.julia\packages\JLLWrappers\jXOYx\src\toplevel_generators.jl:145
#  [5] top-level scope
#    @ C:\Users\Ivan\.julia\packages\JLLWrappers\jXOYx\src\toplevel_generators.jl:160
#  [6] include
#    @ .\Base.jl:495 [inlined]
#  [7] include_package_for_output(pkg::Base.PkgId, input::String, depot_path::Vector{String}, dl_load_path::Vector{String}, load_path::Vector{String}, concrete_deps::Vector{Pair{Base.PkgId, UInt128}}, source::String)
#    @ Base .\loading.jl:2222
#  [8] top-level scope
#    @ stdin:3
# in expression starting at C:\Users\Ivan\.julia\packages\OpenSpecFun_jll\xV9iu\src\OpenSpecFun_jll.jl:2
# in expression starting at stdin:3
# ERROR: LoadError: Failed to precompile OpenSpecFun_jll [efe28fd5-8261-553b-a9e1-b2916fc3738e] to "C:\\Users\\Ivan\\.julia\\compiled\\v1.10\\OpenSpecFun_jll\\jl_A5C1.tmp".
# Stacktrace:
#   [1] error(s::String)
#     @ Base .\error.jl:35
#   [2] compilecache(pkg::Base.PkgId, path::String, internal_stderr::IO, internal_stdout::IO, keep_loaded_modules::Bool)
#     @ Base .\loading.jl:2468
#   [3] compilecache
#     @ .\loading.jl:2340 [inlined]
#   [4] (::Base.var"#968#969"{Base.PkgId})()
#     @ Base .\loading.jl:1974
#   [5] mkpidlock(f::Base.var"#968#969"{Base.PkgId}, at::String, pid::Int32; kwopts::@Kwargs{stale_age::Int64, wait::Bool})
#     @ FileWatching.Pidfile c:\users\ivan\appdata\local\programs\julia-1.10.5\share\julia\stdlib\v1.10\FileWatching\src\pidfile.jl:93
#   [6] #mkpidlock#6
#     @ c:\users\ivan\appdata\local\programs\julia-1.10.5\share\julia\stdlib\v1.10\FileWatching\src\pidfile.jl:88 [inlined]
#   [7] trymkpidlock(::Function, ::Vararg{Any}; kwargs::@Kwargs{stale_age::Int64})
#     @ FileWatching.Pidfile c:\users\ivan\appdata\local\programs\julia-1.10.5\share\julia\stdlib\v1.10\FileWatching\src\pidfile.jl:111
#   [8] #invokelatest#2
#     @ .\essentials.jl:894 [inlined]
#   [9] invokelatest
#     @ .\essentials.jl:889 [inlined]
#  [10] maybe_cachefile_lock(f::Base.var"#968#969"{Base.PkgId}, pkg::Base.PkgId, srcpath::String; stale_age::Int64)
#     @ Base .\loading.jl:2983
#  [11] maybe_cachefile_lock
#     @ .\loading.jl:2980 [inlined]
#  [12] _require(pkg::Base.PkgId, env::String)
#     @ Base .\loading.jl:1970
#  [13] __require_prelocked(uuidkey::Base.PkgId, env::String)
#     @ Base .\loading.jl:1812
#  [14] #invoke_in_world#3
#     @ .\essentials.jl:926 [inlined]
#  [15] invoke_in_world
#     @ .\essentials.jl:923 [inlined]
#  [16] _require_prelocked(uuidkey::Base.PkgId, env::String)
#     @ Base .\loading.jl:1803
#  [17] macro expansion
#     @ .\loading.jl:1790 [inlined]
#  [18] macro expansion
#     @ .\lock.jl:267 [inlined]
#  [19] __require(into::Module, mod::Symbol)
#     @ Base .\loading.jl:1753
#  [20] #invoke_in_world#3
#     @ .\essentials.jl:926 [inlined]
#  [21] invoke_in_world
#     @ .\essentials.jl:923 [inlined]
#  [22] require(into::Module, mod::Symbol)
#     @ Base .\loading.jl:1746
#  [23] include
#     @ .\Base.jl:495 [inlined]
#  [24] include_package_for_output(pkg::Base.PkgId, input::String, depot_path::Vector{String}, dl_load_path::Vector{String}, load_path::Vector{String}, concrete_deps::Vector{Pair{Base.PkgId, UInt128}}, source::String)
#     @ Base .\loading.jl:2222
#  [25] top-level scope
#     @ stdin:3
# in expression starting at C:\Users\Ivan\.julia\packages\SpecialFunctions\Zijv9\src\SpecialFunctions.jl:1
# in expression starting at stdin:3
# ERROR: LoadError: Failed to precompile SpecialFunctions [276daf66-3868-5448-9aa4-cd146d93841b] to "C:\\Users\\Ivan\\.julia\\compiled\\v1.10\\SpecialFunctions\\jl_A459.tmp".
# Stacktrace:
#   [1] error(s::String)
#     @ Base .\error.jl:35
#   [2] compilecache(pkg::Base.PkgId, path::String, internal_stderr::IO, internal_stdout::IO, keep_loaded_modules::Bool)
#     @ Base .\loading.jl:2468
#   [3] compilecache
#     @ .\loading.jl:2340 [inlined]
#   [4] (::Base.var"#968#969"{Base.PkgId})()
#     @ Base .\loading.jl:1974
#   [5] mkpidlock(f::Base.var"#968#969"{Base.PkgId}, at::String, pid::Int32; kwopts::@Kwargs{stale_age::Int64, wait::Bool})
#     @ FileWatching.Pidfile c:\users\ivan\appdata\local\programs\julia-1.10.5\share\julia\stdlib\v1.10\FileWatching\src\pidfile.jl:93
#   [6] #mkpidlock#6
#     @ c:\users\ivan\appdata\local\programs\julia-1.10.5\share\julia\stdlib\v1.10\FileWatching\src\pidfile.jl:88 [inlined]
#   [7] trymkpidlock(::Function, ::Vararg{Any}; kwargs::@Kwargs{stale_age::Int64})
#     @ FileWatching.Pidfile c:\users\ivan\appdata\local\programs\julia-1.10.5\share\julia\stdlib\v1.10\FileWatching\src\pidfile.jl:111
#   [8] #invokelatest#2
#     @ .\essentials.jl:894 [inlined]
#   [9] invokelatest
#     @ .\essentials.jl:889 [inlined]
#  [10] maybe_cachefile_lock(f::Base.var"#968#969"{Base.PkgId}, pkg::Base.PkgId, srcpath::String; stale_age::Int64)
#     @ Base .\loading.jl:2983
#  [11] maybe_cachefile_lock
#     @ .\loading.jl:2980 [inlined]
#  [12] _require(pkg::Base.PkgId, env::String)
#     @ Base .\loading.jl:1970
#  [13] __require_prelocked(uuidkey::Base.PkgId, env::String)
#     @ Base .\loading.jl:1812
#  [14] #invoke_in_world#3
#     @ .\essentials.jl:926 [inlined]
#  [15] invoke_in_world
#     @ .\essentials.jl:923 [inlined]
#  [16] _require_prelocked(uuidkey::Base.PkgId, env::String)
#     @ Base .\loading.jl:1803
#  [17] macro expansion
#     @ .\loading.jl:1790 [inlined]
#  [18] macro expansion
#     @ .\lock.jl:267 [inlined]
#  [19] __require(into::Module, mod::Symbol)
#     @ Base .\loading.jl:1753
#  [20] #invoke_in_world#3
#     @ .\essentials.jl:926 [inlined]
#  [21] invoke_in_world
#     @ .\essentials.jl:923 [inlined]
#  [22] require(into::Module, mod::Symbol)
#     @ Base .\loading.jl:1746
#  [23] include
#     @ .\Base.jl:495 [inlined]
#  [24] include_package_for_output(pkg::Base.PkgId, input::String, depot_path::Vector{String}, dl_load_path::Vector{String}, load_path::Vector{String}, concrete_deps::Vector{Pair{Base.PkgId, UInt128}}, source::String)
#     @ Base .\loading.jl:2222
#  [25] top-level scope
#     @ stdin:3
# in expression starting at C:\Users\Ivan\.julia\packages\ColorVectorSpace\QI5vM\src\ColorVectorSpace.jl:1
# in expression starting at stdin:3
# ERROR: LoadError: Failed to precompile ColorVectorSpace [c3611d14-8923-5661-9e6a-0046d554d3a4] to "C:\\Users\\Ivan\\.julia\\compiled\\v1.10\\ColorVectorSpace\\jl_A1E8.tmp".
# Stacktrace:
#   [1] error(s::String)
#     @ Base .\error.jl:35
#   [2] compilecache(pkg::Base.PkgId, path::String, internal_stderr::IO, internal_stdout::IO, keep_loaded_modules::Bool)
#     @ Base .\loading.jl:2468
#   [3] compilecache
#     @ .\loading.jl:2340 [inlined]
#   [4] (::Base.var"#968#969"{Base.PkgId})()
#     @ Base .\loading.jl:1974
#   [5] mkpidlock(f::Base.var"#968#969"{Base.PkgId}, at::String, pid::Int32; kwopts::@Kwargs{stale_age::Int64, wait::Bool})
#     @ FileWatching.Pidfile c:\users\ivan\appdata\local\programs\julia-1.10.5\share\julia\stdlib\v1.10\FileWatching\src\pidfile.jl:93
#   [6] #mkpidlock#6
#     @ c:\users\ivan\appdata\local\programs\julia-1.10.5\share\julia\stdlib\v1.10\FileWatching\src\pidfile.jl:88 [inlined]
#   [7] trymkpidlock(::Function, ::Vararg{Any}; kwargs::@Kwargs{stale_age::Int64})
#     @ FileWatching.Pidfile c:\users\ivan\appdata\local\programs\julia-1.10.5\share\julia\stdlib\v1.10\FileWatching\src\pidfile.jl:111
#   [8] #invokelatest#2
#     @ .\essentials.jl:894 [inlined]
#   [9] invokelatest
#     @ .\essentials.jl:889 [inlined]
#  [10] maybe_cachefile_lock(f::Base.var"#968#969"{Base.PkgId}, pkg::Base.PkgId, srcpath::String; stale_age::Int64)
#     @ Base .\loading.jl:2983
#  [11] maybe_cachefile_lock
#     @ .\loading.jl:2980 [inlined]
#  [12] _require(pkg::Base.PkgId, env::String)
#     @ Base .\loading.jl:1970
#  [13] __require_prelocked(uuidkey::Base.PkgId, env::String)
#     @ Base .\loading.jl:1812
#  [14] #invoke_in_world#3
#     @ .\essentials.jl:926 [inlined]
#  [15] invoke_in_world
#     @ .\essentials.jl:923 [inlined]
#  [16] _require_prelocked(uuidkey::Base.PkgId, env::String)
#     @ Base .\loading.jl:1803
#  [17] macro expansion
#     @ .\loading.jl:1790 [inlined]
#  [18] macro expansion
#     @ .\lock.jl:267 [inlined]
#  [19] __require(into::Module, mod::Symbol)
#     @ Base .\loading.jl:1753
#  [20] #invoke_in_world#3
#     @ .\essentials.jl:926 [inlined]
#  [21] invoke_in_world
#     @ .\essentials.jl:923 [inlined]
#  [22] require(into::Module, mod::Symbol)
#     @ Base .\loading.jl:1746
#  [23] include
#     @ .\Base.jl:495 [inlined]
#  [24] include_package_for_output(pkg::Base.PkgId, input::String, depot_path::Vector{String}, dl_load_path::Vector{String}, load_path::Vector{String}, concrete_deps::Vector{Pair{Base.PkgId, UInt128}}, source::String)
#     @ Base .\loading.jl:2222
#  [25] top-level scope
#     @ stdin:3
# in expression starting at C:\Users\Ivan\.julia\packages\ImageCore\wTsMr\src\ImageCore.jl:1
# in expression starting at stdin:3
# ERROR: LoadError: Failed to precompile ImageCore [a09fc81d-aa75-5fe9-8630-4744c3626534] to "C:\\Users\\Ivan\\.julia\\compiled\\v1.10\\ImageCore\\jl_9DC2.tmp".
# Stacktrace:
#   [1] error(s::String)
#     @ Base .\error.jl:35
#   [2] compilecache(pkg::Base.PkgId, path::String, internal_stderr::IO, internal_stdout::IO, keep_loaded_modules::Bool)
#     @ Base .\loading.jl:2468
#   [3] compilecache
#     @ .\loading.jl:2340 [inlined]
#   [4] (::Base.var"#968#969"{Base.PkgId})()
#     @ Base .\loading.jl:1974
#   [5] mkpidlock(f::Base.var"#968#969"{Base.PkgId}, at::String, pid::Int32; kwopts::@Kwargs{stale_age::Int64, wait::Bool})
#     @ FileWatching.Pidfile c:\users\ivan\appdata\local\programs\julia-1.10.5\share\julia\stdlib\v1.10\FileWatching\src\pidfile.jl:93
#   [6] #mkpidlock#6
#     @ c:\users\ivan\appdata\local\programs\julia-1.10.5\share\julia\stdlib\v1.10\FileWatching\src\pidfile.jl:88 [inlined]
#   [7] trymkpidlock(::Function, ::Vararg{Any}; kwargs::@Kwargs{stale_age::Int64})
#     @ FileWatching.Pidfile c:\users\ivan\appdata\local\programs\julia-1.10.5\share\julia\stdlib\v1.10\FileWatching\src\pidfile.jl:111
#   [8] #invokelatest#2
#     @ .\essentials.jl:894 [inlined]
#   [9] invokelatest
#     @ .\essentials.jl:889 [inlined]
#  [10] maybe_cachefile_lock(f::Base.var"#968#969"{Base.PkgId}, pkg::Base.PkgId, srcpath::String; stale_age::Int64)
#     @ Base .\loading.jl:2983
#  [11] maybe_cachefile_lock
#     @ .\loading.jl:2980 [inlined]
#  [12] _require(pkg::Base.PkgId, env::String)
#     @ Base .\loading.jl:1970
#  [13] __require_prelocked(uuidkey::Base.PkgId, env::String)
#     @ Base .\loading.jl:1812
#  [14] #invoke_in_world#3
#     @ .\essentials.jl:926 [inlined]
#  [15] invoke_in_world
#     @ .\essentials.jl:923 [inlined]
#  [16] _require_prelocked(uuidkey::Base.PkgId, env::String)
#     @ Base .\loading.jl:1803
#  [17] macro expansion
#     @ .\loading.jl:1790 [inlined]
#  [18] macro expansion
#     @ .\lock.jl:267 [inlined]
#  [19] __require(into::Module, mod::Symbol)
#     @ Base .\loading.jl:1753
#  [20] #invoke_in_world#3
#     @ .\essentials.jl:926 [inlined]
#  [21] invoke_in_world
#     @ .\essentials.jl:923 [inlined]
#  [22] require(into::Module, mod::Symbol)
#     @ Base .\loading.jl:1746
#  [23] include
#     @ .\Base.jl:495 [inlined]
#  [24] include_package_for_output(pkg::Base.PkgId, input::String, depot_path::Vector{String}, dl_load_path::Vector{String}, load_path::Vector{String}, concrete_deps::Vector{Pair{Base.PkgId, UInt128}}, source::Nothing)
#     @ Base .\loading.jl:2222
#  [25] top-level scope
#     @ stdin:3
# in expression starting at C:\Users\Ivan\.julia\packages\ImageMagick\b8swT\src\ImageMagick.jl:1
# in expression starting at stdin:3
# All errors:
# ===========================================
# Failed to precompile PNGFiles [f57f5aa1-a3ce-4bc8-8ab9-96f992907883] to "C:\\Users\\Ivan\\.julia\\compiled\\v1.10\\PNGFiles\\jl_7CC3.tmp".
# ===========================================
# Failed to precompile ImageMagick [6218d12a-5da1-5696-b52f-db25d2ecc6d1] to "C:\\Users\\Ivan\\.julia\\compiled\\v1.10\\ImageMagick\\jl_A0B9.tmp".
# ===========================================
# ArgumentError: Package OpenCV [f878e3a2-a245-4720-8660-60795d644f2a] is required but does not seem to be installed:
#  - Run `Pkg.instantiate()` to install all recorded dependencies.
#
# ===========================================
# Errors encountered while load File{DataFormat{:PNG}, String}("julialogo.png").
#
# Fatal error:
# Failed to precompile PNGFiles [f57f5aa1-a3ce-4bc8-8ab9-96f992907883] to "C:\\Users\\Ivan\\.julia\\compiled\\v1.10\\PNGFiles\\jl_7CC3.tmp".
# Stacktrace:
#   [1] error(s::String)
#     @ Base .\error.jl:35
#   [2] compilecache(pkg::Base.PkgId, path::String, internal_stderr::IO, internal_stdout::IO, keep_loaded_modules::Bool)
#     @ Base .\loading.jl:2468
#   [3] compilecache
#     @ .\loading.jl:2340 [inlined]
#   [4] (::Base.var"#968#969"{Base.PkgId})()
#     @ Base .\loading.jl:1974
#   [5] mkpidlock(f::Base.var"#968#969"{Base.PkgId}, at::String, pid::Int32; kwopts::@Kwargs{stale_age::Int64, wait::Bool})
#     @ FileWatching.Pidfile c:\users\ivan\appdata\local\programs\julia-1.10.5\share\julia\stdlib\v1.10\FileWatching\src\pidfile.jl:93
#   [6] #mkpidlock#6
#     @ c:\users\ivan\appdata\local\programs\julia-1.10.5\share\julia\stdlib\v1.10\FileWatching\src\pidfile.jl:88 [inlined]
#   [7] trymkpidlock(::Function, ::Vararg{Any}; kwargs::@Kwargs{stale_age::Int64})
#     @ FileWatching.Pidfile c:\users\ivan\appdata\local\programs\julia-1.10.5\share\julia\stdlib\v1.10\FileWatching\src\pidfile.jl:111
#   [8] #invokelatest#2
#     @ .\essentials.jl:894 [inlined]
#   [9] invokelatest
#     @ .\essentials.jl:889 [inlined]
#  [10] maybe_cachefile_lock(f::Base.var"#968#969"{Base.PkgId}, pkg::Base.PkgId, srcpath::String; stale_age::Int64)
#     @ Base .\loading.jl:2983
#  [11] maybe_cachefile_lock
#     @ .\loading.jl:2980 [inlined]
#  [12] _require(pkg::Base.PkgId, env::Nothing)
#     @ Base .\loading.jl:1970
#  [13] __require_prelocked(uuidkey::Base.PkgId, env::Nothing)
#     @ Base .\loading.jl:1812
#  [14] #invoke_in_world#3
#     @ .\essentials.jl:926 [inlined]
#  [15] invoke_in_world
#     @ .\essentials.jl:923 [inlined]
#  [16] _require_prelocked
#     @ .\loading.jl:1803 [inlined]
#  [17] _require_prelocked
#     @ .\loading.jl:1802 [inlined]
#  [18] macro expansion
#     @ .\lock.jl:267 [inlined]
#  [19] require(uuidkey::Base.PkgId)
#     @ Base .\loading.jl:1797
#  [20] (::LazyModules.var"#2#3"{Base.PkgId})()
#     @ LazyModules C:\Users\Ivan\.julia\packages\LazyModules\d9Be6\src\LazyModules.jl:56
#  [21] lock(f::LazyModules.var"#2#3"{Base.PkgId}, l::ReentrantLock)
#     @ Base .\lock.jl:229
#  [22] checked_import
#     @ C:\Users\Ivan\.julia\packages\LazyModules\d9Be6\src\LazyModules.jl:54 [inlined]
#  [23] checked_import
#     @ C:\Users\Ivan\.julia\packages\LazyModules\d9Be6\src\LazyModules.jl:65 [inlined]
#  [24] getproperty
#     @ C:\Users\Ivan\.julia\packages\LazyModules\d9Be6\src\LazyModules.jl:40 [inlined]
#  [25] load(f::File{DataFormat{:PNG}, String}; kwargs::@Kwargs{})
#     @ ImageIO C:\Users\Ivan\.julia\packages\ImageIO\Fs42T\src\ImageIO.jl:63
#  [26] load(f::File{DataFormat{:PNG}, String})
#     @ ImageIO C:\Users\Ivan\.julia\packages\ImageIO\Fs42T\src\ImageIO.jl:62
#  [27] #invokelatest#2
#     @ .\essentials.jl:892 [inlined]
#  [28] invokelatest
#     @ .\essentials.jl:889 [inlined]
#  [29] action(::Symbol, ::Vector{Union{Base.PkgId, Module}}, ::Formatted; options::@Kwargs{})
#     @ FileIO C:\Users\Ivan\.julia\packages\FileIO\hnmt7\src\loadsave.jl:219
#  [30] action
#     @ C:\Users\Ivan\.julia\packages\FileIO\hnmt7\src\loadsave.jl:196 [inlined]
#  [31] action
#     @ C:\Users\Ivan\.julia\packages\FileIO\hnmt7\src\loadsave.jl:185 [inlined]
#  [32] load(::String; options::@Kwargs{})
#     @ FileIO C:\Users\Ivan\.julia\packages\FileIO\hnmt7\src\loadsave.jl:113
#  [33] load(::String)
#     @ FileIO C:\Users\Ivan\.julia\packages\FileIO\hnmt7\src\loadsave.jl:109
#  [34] top-level scope
#     @ In[35]:1
#
# Stacktrace:
#  [1] handle_error(e::ErrorException, q::Base.PkgId, bt::Vector{Union{Ptr{Nothing}, Base.InterpreterIP}})
#    @ FileIO C:\Users\Ivan\.julia\packages\FileIO\hnmt7\src\error_handling.jl:71
#  [2] handle_exceptions(exceptions::Vector{Tuple{Any, Union{Base.PkgId, Module}, Vector}}, action::String)
#    @ FileIO C:\Users\Ivan\.julia\packages\FileIO\hnmt7\src\error_handling.jl:66
#  [3] action(::Symbol, ::Vector{Union{Base.PkgId, Module}}, ::Formatted; options::@Kwargs{})
#    @ FileIO C:\Users\Ivan\.julia\packages\FileIO\hnmt7\src\loadsave.jl:228
#  [4] action
#    @ C:\Users\Ivan\.julia\packages\FileIO\hnmt7\src\loadsave.jl:196 [inlined]
#  [5] action
#    @ C:\Users\Ivan\.julia\packages\FileIO\hnmt7\src\loadsave.jl:185 [inlined]
#  [6] load(::String; options::@Kwargs{})
#    @ FileIO C:\Users\Ivan\.julia\packages\FileIO\hnmt7\src\loadsave.jl:113
#  [7] load(::String)
#    @ FileIO C:\Users\Ivan\.julia\packages\FileIO\hnmt7\src\loadsave.jl:109
#  [8] top-level scope
#    @ In[35]:1

# %%
# Определение типа и размера данных:
@show typeof(X1);
@show size(X1);
# Out:
# UndefVarError: `X1` not defined
#
# Stacktrace:
#  [1] macro expansion
#    @ show.jl:1181 [inlined]
#  [2] top-level scope
#    @ In[36]:2

# %% [markdown]
# ### 2. Обработка данных: стандартные алгоритмы машинного обученияв Julia

# %% [markdown]
# #### 2.1. Кластеризация данных. Метод k-средних

# %%
# Загрузка пакетов:
import Pkg
Pkg.add("DataFrames")
Pkg.add("Statistics")
using DataFrames
using CSV
import Pkg
Pkg.add("Plots")
# Out:
#    Resolving package versions...
#   No Changes to `C:\Users\Ivan\.julia\environments\v1.10\Project.toml`
#   No Changes to `C:\Users\Ivan\.julia\environments\v1.10\Manifest.toml`
#    Resolving package versions...
#   No Changes to `C:\Users\Ivan\.julia\environments\v1.10\Project.toml`
#   No Changes to `C:\Users\Ivan\.julia\environments\v1.10\Manifest.toml`
#    Resolving package versions...
#   No Changes to `C:\Users\Ivan\.julia\environments\v1.10\Project.toml`
#   No Changes to `C:\Users\Ivan\.julia\environments\v1.10\Manifest.toml`

# %%
# Загрузка данных:
houses = CSV.File("houses.csv") |> DataFrame
# Out:
# 985×12 DataFrame
#  Row │ street                           city             zip    state    beds  ⋯
#      │ String                           String15         Int64  String3  Int64 ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ 3526 HIGH ST                     SACRAMENTO       95838  CA           2 ⋯
#    2 │ 51 OMAHA CT                      SACRAMENTO       95823  CA           3
#    3 │ 2796 BRANCH ST                   SACRAMENTO       95815  CA           2
#    4 │ 2805 JANETTE WAY                 SACRAMENTO       95815  CA           2
#    5 │ 6001 MCMAHON DR                  SACRAMENTO       95824  CA           2 ⋯
#    6 │ 5828 PEPPERMILL CT               SACRAMENTO       95841  CA           3
#    7 │ 6048 OGDEN NASH WAY              SACRAMENTO       95842  CA           3
#    8 │ 2561 19TH AVE                    SACRAMENTO       95820  CA           3
#    9 │ 11150 TRINITY RIVER DR Unit 114  RANCHO CORDOVA   95670  CA           2 ⋯
#   10 │ 7325 10TH ST                     RIO LINDA        95673  CA           3
#   11 │ 645 MORRISON AVE                 SACRAMENTO       95838  CA           3
#   ⋮  │                ⋮                        ⋮           ⋮       ⋮       ⋮   ⋱
#  976 │ 5024 CHAMBERLIN CIR              ELK GROVE        95757  CA           3
#  977 │ 2400 INVERNESS DR                LINCOLN          95648  CA           3 ⋯
#  978 │ 5 BISHOPGATE CT                  SACRAMENTO       95823  CA           4
#  979 │ 5601 REXLEIGH DR                 SACRAMENTO       95823  CA           4
#  980 │ 1909 YARNELL WAY                 ELK GROVE        95758  CA           3
#  981 │ 9169 GARLINGTON CT               SACRAMENTO       95829  CA           4 ⋯
#  982 │ 6932 RUSKUT WAY                  SACRAMENTO       95823  CA           3
#  983 │ 7933 DAFFODIL WAY                CITRUS HEIGHTS   95610  CA           3
#  984 │ 8304 RED FOX WAY                 ELK GROVE        95758  CA           4
#  985 │ 3882 YELLOWSTONE LN              EL DORADO HILLS  95762  CA           3 ⋯
#                                                   7 columns and 964 rows omitted

# %%
using CSV
using DataFrames
using Plots
# Загрузка данных из CSV
houses = CSV.read("houses.csv", DataFrame)
# Построение графика
plot(size=(500, 500), leg=false)
x = houses[:, :sq__ft]  # Столбец площади
y = houses[:, :price]   # Столбец цены
scatter(x, y, markersize=3)

# %%
# Фильтрация данных по заданному условию:
filter_houses = houses[houses[!,:sq__ft].>0,:]
# Построение графика:
x = filter_houses[!,:sq__ft]
y = filter_houses[!,:price]
scatter(x,y)

# %%
# Загрузка данных из CSV
filter_houses = CSV.read("houses.csv", DataFrame)
# Проверка на пропущенные значения в данных
if any(ismissing, filter_houses[:, :latitude]) || any(ismissing, filter_houses[:, :longitude])
    error("Данные содержат пропущенные значения в столбцах :latitude или :longitude.")
end
# Определение средней цены для каждого типа домов
mean_prices = combine(groupby(filter_houses, :type), :price => mean => :mean_price)
println("Средние цены для каждого типа домов:")
println(mean_prices)
# Добавление данных :latitude и :longitude
X = filter_houses[:, [:latitude, :longitude]]
# Преобразование DataFrame в матрицу
X = Matrix{Float64}(X)'
k = length(unique(filter_houses[:, :zip]))
# Определение кластеров k-среднего
C = kmeans(X, k)
# Формирование DataFrame с результатами кластеризации
df = DataFrame(
    cluster = C.assignments,
    city = filter_houses[:, :city],
    latitude = filter_houses[:, :latitude],
    longitude = filter_houses[:, :longitude],
    zip = filter_houses[:, :zip]
)
# Построение графика кластеров
clusters_figure = plot(legend=false)
for i in 1:k
    clustered_houses = df[df[:, :cluster] .== i, :]
    xvals = clustered_houses[:, :latitude]
    yvals = clustered_houses[:, :longitude]
    scatter!(clusters_figure, xvals, yvals, markersize=4)
end
xlabel!("Latitude")
ylabel!("Longitude")
title!("Houses color-coded by cluster")
display(clusters_figure)
# Out:
# Средние цены для каждого типа домов:
# 4×2 DataFrame
#  Row │ type          mean_price
#      │ String15      Float64
# ─────┼──────────────────────────────
#    1 │ Residential        2.39186e5
#    2 │ Condo              1.50082e5
#    3 │ Multi-Family       2.24535e5
#    4 │ Unkown        275000.0

# %%
unique_zips = unique(filter_houses[!,:zip])
zips_figure = plot(legend = false)
for uzip in unique_zips
    subs = filter_houses[filter_houses[!,:zip].==uzip,:]
    x = subs[!,:latitude]
    y = subs[!,:longitude]
    scatter!(zips_figure,x,y)
end
xlabel!("Latitude")
ylabel!("Longitude")
title!("Houses color-coded by zip code")
display(zips_figure)

# %% [markdown]
# #### 2.2. Кластеризация данных. Метод k ближайших соседей

# %%
# Подключение пакета NearestNeighbors:
import Pkg
Pkg.add("NearestNeighbors")
using NearestNeighbors
knearest = 10
id = 70
point = X[:,id]
# Поиск ближайших соседей:
kdtree = KDTree(X)
idxs, dists = knn(kdtree, point, knearest, true)
# Все объекты недвижимости:
x = filter_houses[!,:latitude];
y = filter_houses[!,:longitude];
scatter(x,y)
# Соседи:
x = filter_houses[idxs,:latitude];
y = filter_houses[idxs,:longitude];
scatter!(x,y)
# Out:
#    Resolving package versions...
#     Updating `C:\Users\Ivan\.julia\environments\v1.10\Project.toml`
#   [b8a86587] + NearestNeighbors v0.4.21
#   No Changes to `C:\Users\Ivan\.julia\environments\v1.10\Manifest.toml`

# %%
# Фильтрация по районам соседних домов:
cities = filter_houses[idxs,:city]
# Out:
# 10-element PooledArrays.PooledVector{String15, UInt32, Vector{UInt32}}:
#  "SACRAMENTO"
#  "ELK GROVE"
#  "SACRAMENTO"
#  "SACRAMENTO"
#  "SACRAMENTO"
#  "SACRAMENTO"
#  "ELK GROVE"
#  "ELK GROVE"
#  "ELK GROVE"
#  "ELK GROVE"

# %% [markdown]
# #### 2.3. Обработка данных. Метод главных компонент

# %%
# Фрейм с указанием площади и цены недвижимости:
F = filter_houses[[:sq__ft,:price]]
# Конвертация данных в массив:
F = convert(Array{Float64,2},F)'
# Подключение пакета MultivariateStats:
import Pkg
Pkg.add("MultivariateStats")
using MultivariateStats
# Приведение типов данных к распределению для PCA:
M = fit(PCA, F)
# Выделение значений главных компонент в отдельную переменную:
Xr = reconstruct(M, y)
# Построение графика с выделением главных компонент:
scatter(F[1,:],F[2,:])
scatter!(Xr[1,:],Xr[2,:])

# %% [markdown]
# #### 2.4. Обработка данных. Линейная регрессия

# %%
xvals = repeat(1:0.5:10,inner=2)
yvals = 3 .+ xvals + 2*rand(length(xvals)) .- 1
scatter(xvals,yvals,color=:black,leg=false)

# %%
function find_best_fit(xvals,yvals)
    meanx = mean(xvals)
    meany = mean(yvals)
    stdx = std(xvals)
    stdy = std(yvals)
    r = cor(xvals,yvals)
    a = r*stdy/stdx
    b = meany - a*meanx
    return a,b
end
a,b = find_best_fit(xvals,yvals)
ynew = a * xvals .+ b
plot!(xvals,ynew)

# %%
xvals = 1:100000;
xvals = repeat(xvals,inner=3);
yvals = 3 .+ xvals + 2*rand(length(xvals)) .- 1;
@show size(xvals)
@show size(yvals)
@time a,b = find_best_fit(xvals,yvals)
import Pkg
Pkg.add("PyCall")
Pkg.add("Conda")
using PyCall
using Conda
py"""
import numpy
def find_best_fit_python(xvals,yvals):
    meanx = numpy.mean(xvals)
    meany = numpy.mean(yvals)
    stdx = numpy.std(xvals)
    stdy = numpy.std(yvals)
    r = numpy.corrcoef(xvals,yvals)[0][1]
    a = r*stdy/stdx
    b = meany - a*meanx
    return a,b
"""
xpy = PyObject(xvals)
ypy = PyObject(yvals)
@time a,b = find_best_fit_python(xpy,ypy)
import Pkg
Pkg.add("BenchmarkTools")
using BenchmarkTools
@btime a,b = find_best_fit_python(xvals,yvals)
@btime a,b = find_best_fit(xvals,yvals)

# %% [markdown]
# ### Самостоятельное выполнение

# %% [markdown]
# #### 1.1) Кластеризация

# %%
# Загрузка данных
iris = dataset("datasets", "iris")
# Преобразуем DataFrame в матрицу
X = Matrix{Float64}(iris[:, 1:4])  # Используем только числовые признаки
# Применяем кластеризацию методом k-средних
k = 3  # Количество кластеров
result = kmeans(X, k)
# Визуализация кластеров
scatter(X[:, 1], X[:, 2], group = result.assignments, xlabel = "Sepal Length", ylabel = "Sepal Width", title = "K-means Clustering")

# %% [markdown]
# #### 1.2) Регрессия (метод наименьших квадратов в случае линейной регрессии)

# %% [markdown]
# ##### Часть 1.

# %%
# Генерация данных
X = randn(1000, 3)
a0 = rand(3)
y = X * a0 + 0.1 * randn(1000)
# Добавляем столбец единиц в X для учета свободного члена
X2 = hcat(ones(1000), X)
# Применяем ридж-регрессию с небольшим значением регуляризации
ridge_result = ridge(X2, y, 1e-4)
println("Ридж-регрессия, коэффициенты:")
println(ridge_result)
# Сравнение с использованием GLM.jl
# Преобразуем X2 в DataFrame, чтобы использовать его с GLM
df = DataFrame(X2 = hcat(ones(1000), X)..., y = y)  # Распаковываем X2 в отдельные столбцы
model = lm(@formula(y ~ X2), df)
println("Результаты с использованием GLM.jl:")
println(coef(model))

# %% [markdown]
# ##### Часть 2.

# %%
# Генерация данных
X = rand(100)
y = 2 * X + 0.1 * randn(100)
# Построение графика данных
scatter(X, y, label="Data", xlabel="X", ylabel="y", title="Regression Plot")
# Линейная регрессия
X2 = hcat(ones(100), X)  # Добавляем столбец единиц
beta = (X2' * X2) \ (X2' * y)
# Добавление линии регрессии
plot!(X, x -> beta[1] + beta[2] * x, label="Regression Line", color=:red)

# %% [markdown]
# #### 1.3) Модель ценообразования биномиальных опционов

# %% [markdown]
# ##### a.

# %%
# Параметры модели
S = 100      # Начальная цена акции
T = 1        # Длительность в годах
n = 10000    # Количество периодов
sigma = 0.3  # Волатильность
r = 0.08     # Годовая процентная ставка
h = T / n    # Длина одного периода

# Расчет u и d
u = exp(r * h + sigma * sqrt(h))
d = exp(r * h - sigma * sqrt(h))

# Цена акции на каждом шаге
function create_path(S, r, sigma, T, n)
    path = zeros(Float64, n+1)
    path[1] = S 
    for i in 2:n+1
        if rand() > 0.5  # Пример случайного выбора направления
            path[i] = path[i-1] * u
        else
            path[i] = path[i-1] * d
        end
    end
    return path
end
# Генерация и построение траектории
path = create_path(S, r, sigma, T, n)
plot(path, label="Stock Price Path", xlabel="Time Step", ylabel="Price", title="Stock Price Trajectory")

# %% [markdown]
# ##### b.

# %%
# Генерация 10 траекторий
paths = [create_path(S, r, sigma, T, n) for _ in 1:10]
# Построение всех траекторий на одном графике
for path in paths
    plot!(path, label="Trajectory", xlabel="Time Step", ylabel="Price", title="Multiple Stock Price Trajectories")
end

# %% [markdown]
# ##### c.

# %%
using Threads
# Функция для параллельной генерации траекторий
function parallel_paths(n_paths)
    paths = Vector{Array{Float64, 1}}(undef, n_paths)
    Threads.@threads for i in 1:n_paths
        paths[i] = create_path(S, r, sigma, T, n)
    end
    return paths
end
# Генерация траекторий с использованием многозадачности
paths_parallel = parallel_paths(10)
# Построение всех параллельных траекторий
for path in paths_parallel
    plot!(path, label="Trajectory", xlabel="Time Step", ylabel="Price", title="Parallel Stock Price Trajectories")
end
